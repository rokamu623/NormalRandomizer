# %%
from randomizer import normal, data_histgram, show_histgram, two_peak_normal

data_list = normal(100, 10, 100)
# data_list_omake = two_peak_normal(50, 10, 5, 0.2, 10000)
hist, bins = data_histgram(data_list, 10)
print('hist: '+str(['{:.2f}'.format(_) for _ in hist]))
print('bins: '+str(['{:.2f}'.format(_) for _ in bins]))
show_histgram(data_list, 10)
# show_histgram(data_list_omake, 100)
# Out:
# hist: ['3.00', '5.00', '9.00', '6.00', '24.00', '21.00', '16.00', '11.00', '3.00', '2.00']
# bins: ['75.45', '80.36', '85.28', '90.19', '95.10', '100.02', '104.93', '109.85', '114.76', '119.68', '124.59']
