# %%
from randomizer import normal, data_histgram, show_histgram

data_list = normal(100, 10, 100)
hist, bins = data_histgram(data_list, 10)
print('hist: '+str(['{:.2f}'.format(_) for _ in hist]))
print('bins: '+str(['{:.2f}'.format(_) for _ in bins]))
show_histgram(data_list, 10)
# Out:
# hist: ['8.00', '5.00', '12.00', '24.00', '18.00', '18.00', '11.00', '1.00', '2.00', '1.00']
# bins: ['77.26', '82.83', '88.39', '93.96', '99.52', '105.08', '110.65', '116.21', '121.77', '127.34', '132.90']
